# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-raj-07/PW_Library/blob/main/EDA_US_VISA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


import warnings
warnings.filterwarnings('ignore')

plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option("display.max_columns", 30)

# %%
df = pd.read_csv("us_perm_visas.csv")

# %%
df
# Out:
#       add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                             NaN         NaN              NaN          NaN
# 1                             NaN         NaN              NaN          NaN
# 2                             NaN         NaN              NaN          NaN
# 3                             NaN         NaN              NaN          NaN
# 4                             NaN         NaN              NaN          NaN
# ...                           ...         ...              ...          ...
# 7211                          NaN         NaN              NaN          NaN
# 7212                          NaN         NaN              NaN          NaN
# 7213                          NaN         NaN              NaN          NaN
# 7214                          NaN         NaN              NaN          NaN
# 7215                          NaN         NaN              NaN          NaN
#
#      application_type        case_no  case_number  case_received_date  \
# 0                PERM  A-07323-97014          NaN                 NaN
# 1                PERM  A-07332-99439          NaN                 NaN
# 2                PERM  A-07333-99643          NaN                 NaN
# 3                PERM  A-07339-01930          NaN                 NaN
# 4                PERM  A-07345-03565          NaN                 NaN
# ...               ...            ...          ...                 ...
# 7211             PERM  A-11200-93805          NaN                 NaN
# 7212             PERM  A-11200-93806          NaN                 NaN
# 7213             PERM  A-11200-93807          NaN                 NaN
# 7214             PERM  A-11200-93809          NaN                 NaN
# 7215             PERM  A-11200-93812          NaN                 NaN
#
#             case_status class_of_admission  country_of_citizenship  \
# 0             Certified                J-1                     NaN
# 1                Denied                B-2                     NaN
# 2             Certified               H-1B                     NaN
# 3             Certified                B-2                     NaN
# 4             Certified                L-1                     NaN
# ...                 ...                ...                     ...
# 7211  Certified-Expired               H-1B                     NaN
# 7212  Certified-Expired               H-1B                     NaN
# 7213          Certified               H-1B                     NaN
# 7214          Certified               H-1B                     NaN
# 7215  Certified-Expired               H-1B                     NaN
#
#      country_of_citzenship decision_date          employer_address_1  \
# 0                  ARMENIA    2012-02-01           24 WEST 25 STREET
# 1                   POLAND    2011-12-21            200 BROAD STREET
# 2                    INDIA    2011-12-01  1054 TECHNOLOGY PARK DRIVE
# 3              SOUTH KOREA    2011-12-01     33-17 PRINCE ST. 2ND FL
# 4                   CANADA    2012-01-26               1373 BROADWAY
# ...                    ...           ...                         ...
# 7211                 NEPAL    2011-10-28              200 1ST ST. SW
# 7212                 INDIA    2011-10-26     1001 FANNIN, SUITE 4000
# 7213                 INDIA    2012-03-09           101 HUDSON STREET
# 7214        UNITED KINGDOM    2011-11-08        601 WEST 26TH STREET
# 7215                JORDAN    2011-10-03       4605 LANKERSHIM BLVD.
#
#                 employer_address_2  ... ri_layoff_in_past_six_months  \
# 0                        5TH FLOOR  ...                          NaN
# 1                              NaN  ...                          NaN
# 2                              NaN  ...                          NaN
# 3                              NaN  ...                          NaN
# 4                              NaN  ...                          NaN
# ...                            ...  ...                          ...
# 7211  PLUMMER 7 (LEGAL DEPARTMENT)  ...                          NaN
# 7212                           NaN  ...                          NaN
# 7213                  SUITE # 3715  ...                          NaN
# 7214                    SUITE 1820  ...                          NaN
# 7215                     SUITE 617  ...                          NaN
#
#       ri_local_ethnic_paper_from  ri_local_ethnic_paper_to  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 7211                         NaN                       NaN
# 7212                         NaN                       NaN
# 7213                         NaN                       NaN
# 7214                         NaN                       NaN
# 7215                         NaN                       NaN
#
#      ri_posted_notice_at_worksite  ri_pvt_employment_firm_from  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 7211                          NaN                          NaN
# 7212                          NaN                          NaN
# 7213                          NaN                          NaN
# 7214                          NaN                          NaN
# 7215                          NaN                          NaN
#
#       ri_pvt_employment_firm_to  ri_us_workers_considered  schd_a_sheepherder  \
# 0                           NaN                       NaN                 NaN
# 1                           NaN                       NaN                 NaN
# 2                           NaN                       NaN                 NaN
# 3                           NaN                       NaN                 NaN
# 4                           NaN                       NaN                 NaN
# ...                         ...                       ...                 ...
# 7211                        NaN                       NaN                 NaN
# 7212                        NaN                       NaN                 NaN
# 7213                        NaN                       NaN                 NaN
# 7214                        NaN                       NaN                 NaN
# 7215                        NaN                       NaN                 NaN
#
#          us_economic_sector  wage_offer_from_9089  wage_offer_to_9089  \
# 0                        IT              75629.00                 NaN
# 1     Other Economic Sector              37024.00                 NaN
# 2                 Aerospace              47923.00                 NaN
# 3     Other Economic Sector                 10.97                 NaN
# 4              Advanced Mfg             100000.00                 NaN
# ...                     ...                   ...                 ...
# 7211   Educational Services             216000.00                 NaN
# 7212  Other Economic Sector             104915.00                 NaN
# 7213                     IT             101090.00                 NaN
# 7214           Advanced Mfg              83866.00                 NaN
# 7215                    NaN                   NaN                 NaN
#
#       wage_offer_unit_of_pay_9089  wage_offered_from_9089  \
# 0                              yr                     NaN
# 1                              yr                     NaN
# 2                              yr                     NaN
# 3                              hr                     NaN
# 4                              yr                     NaN
# ...                           ...                     ...
# 7211                           yr                     NaN
# 7212                           yr                     NaN
# 7213                           yr                     NaN
# 7214                           yr                     NaN
# 7215                          NaN                     NaN
#
#       wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
# 3                      NaN                            NaN
# 4                      NaN                            NaN
# ...                    ...                            ...
# 7211                   NaN                            NaN
# 7212                   NaN                            NaN
# 7213                   NaN                            NaN
# 7214                   NaN                            NaN
# 7215                   NaN                            NaN
#
# [7216 rows x 154 columns]

# %%
df.shape
# Out:
# (7216, 154)

# %%
df.dtypes
# Out:
# add_these_pw_job_title_9089      float64
# agent_city                       float64
# agent_firm_name                  float64
# agent_state                      float64
# application_type                  object
#                                   ...
# wage_offer_to_9089               float64
# wage_offer_unit_of_pay_9089       object
# wage_offered_from_9089           float64
# wage_offered_to_9089             float64
# wage_offered_unit_of_pay_9089    float64
# Length: 154, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7216 entries, 0 to 7215
# Columns: 154 entries, add_these_pw_job_title_9089 to wage_offered_unit_of_pay_9089
# dtypes: float64(131), object(23)
# memory usage: 8.5+ MB

# %%
df.isnull().sum()
# Out:
# add_these_pw_job_title_9089      7216
# agent_city                       7216
# agent_firm_name                  7216
# agent_state                      7216
# application_type                    0
#                                  ...
# wage_offer_to_9089               5580
# wage_offer_unit_of_pay_9089         1
# wage_offered_from_9089           7216
# wage_offered_to_9089             7216
# wage_offered_unit_of_pay_9089    7216
# Length: 154, dtype: int64

# %%
df.describe()
# Out:
#        add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# count                          0.0         0.0              0.0          0.0
# mean                           NaN         NaN              NaN          NaN
# std                            NaN         NaN              NaN          NaN
# min                            NaN         NaN              NaN          NaN
# 25%                            NaN         NaN              NaN          NaN
# 50%                            NaN         NaN              NaN          NaN
# 75%                            NaN         NaN              NaN          NaN
# max                            NaN         NaN              NaN          NaN
#
#        case_number  case_received_date  country_of_citizenship  \
# count          0.0                 0.0                     0.0
# mean           NaN                 NaN                     NaN
# std            NaN                 NaN                     NaN
# min            NaN                 NaN                     NaN
# 25%            NaN                 NaN                     NaN
# 50%            NaN                 NaN                     NaN
# 75%            NaN                 NaN                     NaN
# max            NaN                 NaN                     NaN
#
#        employer_country  employer_decl_info_title  employer_num_employees  \
# count               0.0                       0.0                     0.0
# mean                NaN                       NaN                     NaN
# std                 NaN                       NaN                     NaN
# min                 NaN                       NaN                     NaN
# 25%                 NaN                       NaN                     NaN
# 50%                 NaN                       NaN                     NaN
# 75%                 NaN                       NaN                     NaN
# max                 NaN                       NaN                     NaN
#
#        employer_phone  employer_phone_ext  employer_postal_code  \
# count             0.0                 0.0           7214.000000
# mean              NaN                 NaN          49005.388134
# std               NaN                 NaN          34362.393210
# min               NaN                 NaN            646.000000
# 25%               NaN                 NaN          14230.750000
# 50%               NaN                 NaN          46202.000000
# 75%               NaN                 NaN          90010.000000
# max               NaN                 NaN          99210.000000
#
#        employer_yr_estab  foreign_worker_info_alt_edu_experience  ...  \
# count                0.0                                     0.0  ...
# mean                 NaN                                     NaN  ...
# std                  NaN                                     NaN  ...
# min                  NaN                                     NaN  ...
# 25%                  NaN                                     NaN  ...
# 50%                  NaN                                     NaN  ...
# 75%                  NaN                                     NaN  ...
# max                  NaN                                     NaN  ...
#
#        ri_job_search_website_from  ri_job_search_website_to  \
# count                         0.0                       0.0
# mean                          NaN                       NaN
# std                           NaN                       NaN
# min                           NaN                       NaN
# 25%                           NaN                       NaN
# 50%                           NaN                       NaN
# 75%                           NaN                       NaN
# max                           NaN                       NaN
#
#        ri_layoff_in_past_six_months  ri_local_ethnic_paper_from  \
# count                           0.0                         0.0
# mean                            NaN                         NaN
# std                             NaN                         NaN
# min                             NaN                         NaN
# 25%                             NaN                         NaN
# 50%                             NaN                         NaN
# 75%                             NaN                         NaN
# max                             NaN                         NaN
#
#        ri_local_ethnic_paper_to  ri_posted_notice_at_worksite  \
# count                       0.0                           0.0
# mean                        NaN                           NaN
# std                         NaN                           NaN
# min                         NaN                           NaN
# 25%                         NaN                           NaN
# 50%                         NaN                           NaN
# 75%                         NaN                           NaN
# max                         NaN                           NaN
#
#        ri_pvt_employment_firm_from  ri_pvt_employment_firm_to  \
# count                          0.0                        0.0
# mean                           NaN                        NaN
# std                            NaN                        NaN
# min                            NaN                        NaN
# 25%                            NaN                        NaN
# 50%                            NaN                        NaN
# 75%                            NaN                        NaN
# max                            NaN                        NaN
#
#        ri_us_workers_considered  schd_a_sheepherder  wage_offer_from_9089  \
# count                       0.0                 0.0          7.215000e+03
# mean                        NaN                 NaN          7.831609e+04
# std                         NaN                 NaN          1.118016e+05
# min                         NaN                 NaN          7.250000e+00
# 25%                         NaN                 NaN          4.971200e+04
# 50%                         NaN                 NaN          7.650000e+04
# 75%                         NaN                 NaN          9.655400e+04
# max                         NaN                 NaN          7.651400e+06
#
#        wage_offer_to_9089  wage_offered_from_9089  wage_offered_to_9089  \
# count        1.636000e+03                     0.0                   0.0
# mean         9.709680e+04                     NaN                   NaN
# std          5.781225e+04                     NaN                   NaN
# min          7.250000e+00                     NaN                   NaN
# 25%          7.292000e+04                     NaN                   NaN
# 50%          9.543950e+04                     NaN                   NaN
# 75%          1.205000e+05                     NaN                   NaN
# max          1.115000e+06                     NaN                   NaN
#
#        wage_offered_unit_of_pay_9089
# count                            0.0
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
# [8 rows x 131 columns]

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=154)

# %%
df
# Out:
#       add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                             NaN         NaN              NaN          NaN
# 1                             NaN         NaN              NaN          NaN
# 2                             NaN         NaN              NaN          NaN
# 3                             NaN         NaN              NaN          NaN
# 4                             NaN         NaN              NaN          NaN
# ...                           ...         ...              ...          ...
# 7211                          NaN         NaN              NaN          NaN
# 7212                          NaN         NaN              NaN          NaN
# 7213                          NaN         NaN              NaN          NaN
# 7214                          NaN         NaN              NaN          NaN
# 7215                          NaN         NaN              NaN          NaN
#
#      application_type        case_no  case_number  case_received_date  \
# 0                PERM  A-07323-97014          NaN                 NaN
# 1                PERM  A-07332-99439          NaN                 NaN
# 2                PERM  A-07333-99643          NaN                 NaN
# 3                PERM  A-07339-01930          NaN                 NaN
# 4                PERM  A-07345-03565          NaN                 NaN
# ...               ...            ...          ...                 ...
# 7211             PERM  A-11200-93805          NaN                 NaN
# 7212             PERM  A-11200-93806          NaN                 NaN
# 7213             PERM  A-11200-93807          NaN                 NaN
# 7214             PERM  A-11200-93809          NaN                 NaN
# 7215             PERM  A-11200-93812          NaN                 NaN
#
#             case_status class_of_admission  country_of_citizenship  \
# 0             Certified                J-1                     NaN
# 1                Denied                B-2                     NaN
# 2             Certified               H-1B                     NaN
# 3             Certified                B-2                     NaN
# 4             Certified                L-1                     NaN
# ...                 ...                ...                     ...
# 7211  Certified-Expired               H-1B                     NaN
# 7212  Certified-Expired               H-1B                     NaN
# 7213          Certified               H-1B                     NaN
# 7214          Certified               H-1B                     NaN
# 7215  Certified-Expired               H-1B                     NaN
#
#      country_of_citzenship decision_date          employer_address_1  \
# 0                  ARMENIA    2012-02-01           24 WEST 25 STREET
# 1                   POLAND    2011-12-21            200 BROAD STREET
# 2                    INDIA    2011-12-01  1054 TECHNOLOGY PARK DRIVE
# 3              SOUTH KOREA    2011-12-01     33-17 PRINCE ST. 2ND FL
# 4                   CANADA    2012-01-26               1373 BROADWAY
# ...                    ...           ...                         ...
# 7211                 NEPAL    2011-10-28              200 1ST ST. SW
# 7212                 INDIA    2011-10-26     1001 FANNIN, SUITE 4000
# 7213                 INDIA    2012-03-09           101 HUDSON STREET
# 7214        UNITED KINGDOM    2011-11-08        601 WEST 26TH STREET
# 7215                JORDAN    2011-10-03       4605 LANKERSHIM BLVD.
#
#                 employer_address_2  ... ri_layoff_in_past_six_months  \
# 0                        5TH FLOOR  ...                          NaN
# 1                              NaN  ...                          NaN
# 2                              NaN  ...                          NaN
# 3                              NaN  ...                          NaN
# 4                              NaN  ...                          NaN
# ...                            ...  ...                          ...
# 7211  PLUMMER 7 (LEGAL DEPARTMENT)  ...                          NaN
# 7212                           NaN  ...                          NaN
# 7213                  SUITE # 3715  ...                          NaN
# 7214                    SUITE 1820  ...                          NaN
# 7215                     SUITE 617  ...                          NaN
#
#       ri_local_ethnic_paper_from  ri_local_ethnic_paper_to  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 7211                         NaN                       NaN
# 7212                         NaN                       NaN
# 7213                         NaN                       NaN
# 7214                         NaN                       NaN
# 7215                         NaN                       NaN
#
#      ri_posted_notice_at_worksite  ri_pvt_employment_firm_from  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 7211                          NaN                          NaN
# 7212                          NaN                          NaN
# 7213                          NaN                          NaN
# 7214                          NaN                          NaN
# 7215                          NaN                          NaN
#
#       ri_pvt_employment_firm_to  ri_us_workers_considered  schd_a_sheepherder  \
# 0                           NaN                       NaN                 NaN
# 1                           NaN                       NaN                 NaN
# 2                           NaN                       NaN                 NaN
# 3                           NaN                       NaN                 NaN
# 4                           NaN                       NaN                 NaN
# ...                         ...                       ...                 ...
# 7211                        NaN                       NaN                 NaN
# 7212                        NaN                       NaN                 NaN
# 7213                        NaN                       NaN                 NaN
# 7214                        NaN                       NaN                 NaN
# 7215                        NaN                       NaN                 NaN
#
#          us_economic_sector  wage_offer_from_9089  wage_offer_to_9089  \
# 0                        IT              75629.00                 NaN
# 1     Other Economic Sector              37024.00                 NaN
# 2                 Aerospace              47923.00                 NaN
# 3     Other Economic Sector                 10.97                 NaN
# 4              Advanced Mfg             100000.00                 NaN
# ...                     ...                   ...                 ...
# 7211   Educational Services             216000.00                 NaN
# 7212  Other Economic Sector             104915.00                 NaN
# 7213                     IT             101090.00                 NaN
# 7214           Advanced Mfg              83866.00                 NaN
# 7215                    NaN                   NaN                 NaN
#
#       wage_offer_unit_of_pay_9089  wage_offered_from_9089  \
# 0                              yr                     NaN
# 1                              yr                     NaN
# 2                              yr                     NaN
# 3                              hr                     NaN
# 4                              yr                     NaN
# ...                           ...                     ...
# 7211                           yr                     NaN
# 7212                           yr                     NaN
# 7213                           yr                     NaN
# 7214                           yr                     NaN
# 7215                          NaN                     NaN
#
#       wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
# 3                      NaN                            NaN
# 4                      NaN                            NaN
# ...                    ...                            ...
# 7211                   NaN                            NaN
# 7212                   NaN                            NaN
# 7213                   NaN                            NaN
# 7214                   NaN                            NaN
# 7215                   NaN                            NaN
#
# [7216 rows x 154 columns]

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
#        'foreign_worker_info_req_experience', 'foreign_worker_info_state',
#        'foreign_worker_info_training_comp',
#        'foreign_worker_ownership_interest',
#        'foreign_worker_yr_rel_edu_completed',
#        'fw_info_alt_edu_experience', 'fw_info_birth_country',
#        'fw_info_education_other', 'fw_info_postal_code',
#        'fw_info_rel_occup_exp', 'fw_info_req_experience',
#        'fw_info_training_comp', 'fw_info_yr_rel_edu_completed',
#        'fw_ownership_interest', 'ji_foreign_worker_live_on_premises',
#        'ji_fw_live_on_premises', 'ji_live_in_dom_svc_contract',
#        'ji_live_in_domestic_service',
#        'ji_offered_to_sec_j_foreign_worker', 'ji_offered_to_sec_j_fw',
#        'job_info_alt_cmb_ed_oth_yrs', 'job_info_alt_combo_ed',
#        'job_info_alt_combo_ed_exp', 'job_info_alt_combo_ed_other',
#        'job_info_alt_field', 'job_info_alt_field_name',
#        'job_info_alt_occ', 'job_info_alt_occ_job_title',
#        'job_info_alt_occ_num_months', 'job_info_combo_occupation',
#        'job_info_education', 'job_info_education_other',
#        'job_info_experience', 'job_info_experience_num_months',
#        'job_info_foreign_ed', 'job_info_foreign_lang_req',
#        'job_info_job_req_normal', 'job_info_job_title', 'job_info_major',
#        'job_info_training', 'job_info_training_field',
#        'job_info_training_num_months', 'job_info_work_city',
#        'job_info_work_postal_code', 'job_info_work_state',
#        'naics_2007_us_code', 'naics_2007_us_title', 'naics_code',
#        'naics_title', 'naics_us_code', 'naics_us_code_2007',
#        'naics_us_title', 'naics_us_title_2007', 'orig_case_no',
#        'orig_file_date', 'preparer_info_emp_completed',
#        'preparer_info_title', 'pw_amount_9089', 'pw_determ_date',
#        'pw_expire_date', 'pw_job_title_908', 'pw_job_title_9089',
#        'pw_level_9089', 'pw_soc_code', 'pw_soc_title',
#        'pw_source_name_9089', 'pw_source_name_other_9089', 'pw_track_num',
#        'pw_unit_of_pay_9089', 'rec_info_barg_rep_notified',
#        'recr_info_barg_rep_notified', 'recr_info_coll_teach_comp_proc',
#        'recr_info_coll_univ_teacher', 'recr_info_employer_rec_payment',
#        'recr_info_first_ad_start', 'recr_info_job_fair_from',
#        'recr_info_job_fair_to', 'recr_info_on_campus_recr_from',
#        'recr_info_on_campus_recr_to', 'recr_info_pro_org_advert_from',
#        'recr_info_pro_org_advert_to', 'recr_info_prof_org_advert_from',
#        'recr_info_prof_org_advert_to', 'recr_info_professional_occ',
#        'recr_info_radio_tv_ad_from', 'recr_info_radio_tv_ad_to',
#        'recr_info_second_ad_start', 'recr_info_sunday_newspaper',
#        'recr_info_swa_job_order_end', 'recr_info_swa_job_order_start',
#        'refile', 'ri_1st_ad_newspaper_name', 'ri_2nd_ad_newspaper_name',
#        'ri_2nd_ad_newspaper_or_journal', 'ri_campus_placement_from',
#        'ri_campus_placement_to', 'ri_coll_tch_basic_process',
#        'ri_coll_teach_pro_jnl', 'ri_coll_teach_select_date',
#        'ri_employee_referral_prog_from', 'ri_employee_referral_prog_to',
#        'ri_employer_web_post_from', 'ri_employer_web_post_to',
#        'ri_job_search_website_from', 'ri_job_search_website_to',
#        'ri_layoff_in_past_six_months', 'ri_local_ethnic_paper_from',
#        'ri_local_ethnic_paper_to', 'ri_posted_notice_at_worksite',
#        'ri_pvt_employment_firm_from', 'ri_pvt_employment_firm_to',
#        'ri_us_workers_considered', 'schd_a_sheepherder',
#        'us_economic_sector', 'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089'],
#       dtype=object)

# %%
df['case_number']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 7211   NaN
# 7212   NaN
# 7213   NaN
# 7214   NaN
# 7215   NaN
# Name: case_number, Length: 7216, dtype: float64

# %%
df['case_no']
# Out:
# 0       A-07323-97014
# 1       A-07332-99439
# 2       A-07333-99643
# 3       A-07339-01930
# 4       A-07345-03565
#             ...
# 7211    A-11200-93805
# 7212    A-11200-93806
# 7213    A-11200-93807
# 7214    A-11200-93809
# 7215    A-11200-93812
# Name: case_no, Length: 7216, dtype: object

# %%
df.drop("case_no", axis = 1, inplace=True)

# %%
df
# Out:
#       add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                             NaN         NaN              NaN          NaN
# 1                             NaN         NaN              NaN          NaN
# 2                             NaN         NaN              NaN          NaN
# 3                             NaN         NaN              NaN          NaN
# 4                             NaN         NaN              NaN          NaN
# ...                           ...         ...              ...          ...
# 7211                          NaN         NaN              NaN          NaN
# 7212                          NaN         NaN              NaN          NaN
# 7213                          NaN         NaN              NaN          NaN
# 7214                          NaN         NaN              NaN          NaN
# 7215                          NaN         NaN              NaN          NaN
#
#      application_type  case_number  case_received_date        case_status  \
# 0                PERM          NaN                 NaN          Certified
# 1                PERM          NaN                 NaN             Denied
# 2                PERM          NaN                 NaN          Certified
# 3                PERM          NaN                 NaN          Certified
# 4                PERM          NaN                 NaN          Certified
# ...               ...          ...                 ...                ...
# 7211             PERM          NaN                 NaN  Certified-Expired
# 7212             PERM          NaN                 NaN  Certified-Expired
# 7213             PERM          NaN                 NaN          Certified
# 7214             PERM          NaN                 NaN          Certified
# 7215             PERM          NaN                 NaN  Certified-Expired
#
#      class_of_admission  country_of_citizenship country_of_citzenship  \
# 0                   J-1                     NaN               ARMENIA
# 1                   B-2                     NaN                POLAND
# 2                  H-1B                     NaN                 INDIA
# 3                   B-2                     NaN           SOUTH KOREA
# 4                   L-1                     NaN                CANADA
# ...                 ...                     ...                   ...
# 7211               H-1B                     NaN                 NEPAL
# 7212               H-1B                     NaN                 INDIA
# 7213               H-1B                     NaN                 INDIA
# 7214               H-1B                     NaN        UNITED KINGDOM
# 7215               H-1B                     NaN                JORDAN
#
#      decision_date          employer_address_1            employer_address_2  \
# 0       2012-02-01           24 WEST 25 STREET                     5TH FLOOR
# 1       2011-12-21            200 BROAD STREET                           NaN
# 2       2011-12-01  1054 TECHNOLOGY PARK DRIVE                           NaN
# 3       2011-12-01     33-17 PRINCE ST. 2ND FL                           NaN
# 4       2012-01-26               1373 BROADWAY                           NaN
# ...            ...                         ...                           ...
# 7211    2011-10-28              200 1ST ST. SW  PLUMMER 7 (LEGAL DEPARTMENT)
# 7212    2011-10-26     1001 FANNIN, SUITE 4000                           NaN
# 7213    2012-03-09           101 HUDSON STREET                  SUITE # 3715
# 7214    2011-11-08        601 WEST 26TH STREET                    SUITE 1820
# 7215    2011-10-03       4605 LANKERSHIM BLVD.                     SUITE 617
#
#         employer_city  ...  ri_layoff_in_past_six_months  \
# 0            NEW YORK  ...                           NaN
# 1           CARLSTADT  ...                           NaN
# 2          GLEN ALLEN  ...                           NaN
# 3            FLUSHING  ...                           NaN
# 4              ALBANY  ...                           NaN
# ...               ...  ...                           ...
# 7211        ROCHESTER  ...                           NaN
# 7212          HOUSTON  ...                           NaN
# 7213      JERSEY CITY  ...                           NaN
# 7214         NEW YORK  ...                           NaN
# 7215  NORTH HOLLYWOOD  ...                           NaN
#
#       ri_local_ethnic_paper_from ri_local_ethnic_paper_to  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# ...                          ...                      ...
# 7211                         NaN                      NaN
# 7212                         NaN                      NaN
# 7213                         NaN                      NaN
# 7214                         NaN                      NaN
# 7215                         NaN                      NaN
#
#       ri_posted_notice_at_worksite  ri_pvt_employment_firm_from  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 7211                           NaN                          NaN
# 7212                           NaN                          NaN
# 7213                           NaN                          NaN
# 7214                           NaN                          NaN
# 7215                           NaN                          NaN
#
#       ri_pvt_employment_firm_to  ri_us_workers_considered schd_a_sheepherder  \
# 0                           NaN                       NaN                NaN
# 1                           NaN                       NaN                NaN
# 2                           NaN                       NaN                NaN
# 3                           NaN                       NaN                NaN
# 4                           NaN                       NaN                NaN
# ...                         ...                       ...                ...
# 7211                        NaN                       NaN                NaN
# 7212                        NaN                       NaN                NaN
# 7213                        NaN                       NaN                NaN
# 7214                        NaN                       NaN                NaN
# 7215                        NaN                       NaN                NaN
#
#          us_economic_sector  wage_offer_from_9089  wage_offer_to_9089  \
# 0                        IT              75629.00                 NaN
# 1     Other Economic Sector              37024.00                 NaN
# 2                 Aerospace              47923.00                 NaN
# 3     Other Economic Sector                 10.97                 NaN
# 4              Advanced Mfg             100000.00                 NaN
# ...                     ...                   ...                 ...
# 7211   Educational Services             216000.00                 NaN
# 7212  Other Economic Sector             104915.00                 NaN
# 7213                     IT             101090.00                 NaN
# 7214           Advanced Mfg              83866.00                 NaN
# 7215                    NaN                   NaN                 NaN
#
#       wage_offer_unit_of_pay_9089  wage_offered_from_9089  \
# 0                              yr                     NaN
# 1                              yr                     NaN
# 2                              yr                     NaN
# 3                              hr                     NaN
# 4                              yr                     NaN
# ...                           ...                     ...
# 7211                           yr                     NaN
# 7212                           yr                     NaN
# 7213                           yr                     NaN
# 7214                           yr                     NaN
# 7215                          NaN                     NaN
#
#       wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
# 3                      NaN                            NaN
# 4                      NaN                            NaN
# ...                    ...                            ...
# 7211                   NaN                            NaN
# 7212                   NaN                            NaN
# 7213                   NaN                            NaN
# 7214                   NaN                            NaN
# 7215                   NaN                            NaN
#
# [7216 rows x 153 columns]

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
#        'foreign_worker_info_req_experience', 'foreign_worker_info_state',
#        'foreign_worker_info_training_comp',
#        'foreign_worker_ownership_interest',
#        'foreign_worker_yr_rel_edu_completed',
#        'fw_info_alt_edu_experience', 'fw_info_birth_country',
#        'fw_info_education_other', 'fw_info_postal_code',
#        'fw_info_rel_occup_exp', 'fw_info_req_experience',
#        'fw_info_training_comp', 'fw_info_yr_rel_edu_completed',
#        'fw_ownership_interest', 'ji_foreign_worker_live_on_premises',
#        'ji_fw_live_on_premises', 'ji_live_in_dom_svc_contract',
#        'ji_live_in_domestic_service',
#        'ji_offered_to_sec_j_foreign_worker', 'ji_offered_to_sec_j_fw',
#        'job_info_alt_cmb_ed_oth_yrs', 'job_info_alt_combo_ed',
#        'job_info_alt_combo_ed_exp', 'job_info_alt_combo_ed_other',
#        'job_info_alt_field', 'job_info_alt_field_name',
#        'job_info_alt_occ', 'job_info_alt_occ_job_title',
#        'job_info_alt_occ_num_months', 'job_info_combo_occupation',
#        'job_info_education', 'job_info_education_other',
#        'job_info_experience', 'job_info_experience_num_months',
#        'job_info_foreign_ed', 'job_info_foreign_lang_req',
#        'job_info_job_req_normal', 'job_info_job_title', 'job_info_major',
#        'job_info_training', 'job_info_training_field',
#        'job_info_training_num_months', 'job_info_work_city',
#        'job_info_work_postal_code', 'job_info_work_state',
#        'naics_2007_us_code', 'naics_2007_us_title', 'naics_code',
#        'naics_title', 'naics_us_code', 'naics_us_code_2007',
#        'naics_us_title', 'naics_us_title_2007', 'orig_case_no',
#        'orig_file_date', 'preparer_info_emp_completed',
#        'preparer_info_title', 'pw_amount_9089', 'pw_determ_date',
#        'pw_expire_date', 'pw_job_title_908', 'pw_job_title_9089',
#        'pw_level_9089', 'pw_soc_code', 'pw_soc_title',
#        'pw_source_name_9089', 'pw_source_name_other_9089', 'pw_track_num',
#        'pw_unit_of_pay_9089', 'rec_info_barg_rep_notified',
#        'recr_info_barg_rep_notified', 'recr_info_coll_teach_comp_proc',
#        'recr_info_coll_univ_teacher', 'recr_info_employer_rec_payment',
#        'recr_info_first_ad_start', 'recr_info_job_fair_from',
#        'recr_info_job_fair_to', 'recr_info_on_campus_recr_from',
#        'recr_info_on_campus_recr_to', 'recr_info_pro_org_advert_from',
#        'recr_info_pro_org_advert_to', 'recr_info_prof_org_advert_from',
#        'recr_info_prof_org_advert_to', 'recr_info_professional_occ',
#        'recr_info_radio_tv_ad_from', 'recr_info_radio_tv_ad_to',
#        'recr_info_second_ad_start', 'recr_info_sunday_newspaper',
#        'recr_info_swa_job_order_end', 'recr_info_swa_job_order_start',
#        'refile', 'ri_1st_ad_newspaper_name', 'ri_2nd_ad_newspaper_name',
#        'ri_2nd_ad_newspaper_or_journal', 'ri_campus_placement_from',
#        'ri_campus_placement_to', 'ri_coll_tch_basic_process',
#        'ri_coll_teach_pro_jnl', 'ri_coll_teach_select_date',
#        'ri_employee_referral_prog_from', 'ri_employee_referral_prog_to',
#        'ri_employer_web_post_from', 'ri_employer_web_post_to',
#        'ri_job_search_website_from', 'ri_job_search_website_to',
#        'ri_layoff_in_past_six_months', 'ri_local_ethnic_paper_from',
#        'ri_local_ethnic_paper_to', 'ri_posted_notice_at_worksite',
#        'ri_pvt_employment_firm_from', 'ri_pvt_employment_firm_to',
#        'ri_us_workers_considered', 'schd_a_sheepherder',
#        'us_economic_sector', 'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089'],
#       dtype=object)

# %%
df.case_status
# Out:
# 0               Certified
# 1                  Denied
# 2               Certified
# 3               Certified
# 4               Certified
#               ...
# 7211    Certified-Expired
# 7212    Certified-Expired
# 7213            Certified
# 7214            Certified
# 7215    Certified-Expired
# Name: case_status, Length: 7216, dtype: object

# %%
df = df[df["case_status"]!= "Withdrawn"]

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'Certified-Expired'], dtype=object)

# %%
df.loc[df.case_status == 'Certified-Expired', 'case_status'] = 'Certified'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-e33118a882de> in <cell line: 1>()
# ----> 1 df.loc[df.case_status == 'Certified-Expired', 'case_status'] = 'Certified'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'case_status'

# %%
df.case_status.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-99de529c5979> in <cell line: 1>()
# ----> 1 df.case_status.value_counts()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'case_status'

# %%
df.case_status.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-99de529c5979> in <cell line: 1>()
# ----> 1 df.case_status.value_counts()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'case_status'

# %%
df.dropna(axis=1, how='all', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-710a4dcf10f0> in <cell line: 1>()
# ----> 1 df.dropna(axis=1, how='all', inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in dropna(self, axis, inplace, how)
#    5818         inplace = validate_bool_kwarg(inplace, "inplace")
#    5819         # Validate the axis parameter
# -> 5820         self._get_axis_number(axis or 0)
#    5821
#    5822         if self._can_hold_na:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
# --> 556             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     557
#     558     @final
#
# ValueError: No axis named 1 for object type Series

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b666bf274d0a> in <cell line: 1>()
# ----> 1 df.columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'
